# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    # This is the maximum number of tokens that can be used for thinking
    # 1024 is the minimum allowed value
    thinking_budget=1024,
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget,
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write a one paragraph to recursion.")

# Magic string to trigger redacted thinking
# Redacted thinking is a feature that allows the model to think about the question and then return the answer in a redacted format
# It's useful to avoid hallucinations and to ensure the answer is correct

add_user_message(messages, thinking_test_str)

chat(messages,thinking=True)
# Out:
# Message(id='msg_011CegqHB643pMebhhCYjVdJ', container=None, content=[ThinkingBlock(signature='...', thinking="The user is asking me to write one paragraph about recursion. This is a straightforward request for explanatory text about the concept of recursion in computer science/programming.\n\nI'll write a clear, informative paragraph that explains what recursion is, how it works, and perhaps includes an example or key concepts associated with it.", type='thinking'), TextBlock(citations=None, text="# Recursion\n\nRecursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller, similar subproblems. At its core, a recursive function must have two essential components: a base case that stops the recursion and prevents infinite loops, and a recursive case that moves the problem closer to the base case with each call. This elegant approach mirrors many naturally recursive structures and processes, such as traversing tree data structures
# ...
